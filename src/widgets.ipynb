# %%
dbutils.widgets.dropdown(
    "team_dropdown",
    "CSK", 
    ["CSK", "MI", "RCB", "KKR", "SRH", "DC", "RR", "LSG", "GT", "PBKS"],
    "Dropdown: Select IPL Team"
)
dbutils.widgets.combobox(
    "team_combobox",
    "MI", 
    ["CSK", "MI", "RCB", "KKR", "SRH", "DC", "RR", "LSG", "GT", "PBKS"],
    "Combobox: Select IPL Team"
)
dbutils.widgets.multiselect(
    "team_multiselect",
    "RCB", 
    ["CSK", "MI", "RCB", "KKR", "SRH", "DC", "RR", "LSG", "GT", "PBKS"],
    "Multiselect: Choose Teams"
)
dbutils.widgets.text(
    "team_text",
    "KKR",
    "Text: Enter Team Short Name"
)
team_dropdown = dbutils.widgets.get("team_dropdown")
team_combobox = dbutils.widgets.get("team_combobox")
team_multiselect = dbutils.widgets.get("team_multiselect")
team_text = dbutils.widgets.get("team_text")
print("Dropdown:", team_dropdown)
print("Combobox:", team_combobox)
print("Multiselect:", team_multiselect)
print("Text:", team_text)
dbutils.widgets.getArgument("team_dddd","Error: Cannot Find")
#dbutils.widgets.remove("team_combobox")
#dbutils.widgets.removeAll()
