# %%
from pyspark.sql import *
df = spark.read.csv(
    "/Volumes/workspace/default/practice_volume/sales.csv",
    header=True,
    inferSchema=True
)

display(df)
df.printSchema()

# %%
# %sql
SHOW CATALOGS;
