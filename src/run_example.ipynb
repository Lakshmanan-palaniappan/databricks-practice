# %%
result = dbutils.notebook.run(
    "/Workspace/sample",
    timeout_seconds=180,
    arguments={
        "input_path": "/Volumes/dev/bronze/databricks-practice/csv/sales.csv",
        "row_limit": "10"
    }
)
print("Notebook finished with result:", result)
